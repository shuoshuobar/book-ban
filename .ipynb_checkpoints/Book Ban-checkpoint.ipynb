# %%
import pandas as pd

# %% [markdown]
# # 2023-2024:

# %%
df_2024_State = pd.read_excel("2023-2024.xlsx", sheet_name="Sorted by State & District")
df_2024_State.head()
# Out:
#                                     Title            Author  \
# 0                    Call Me By Your Name     Aciman, André
# 1                              The Haters    Andrews, Jesse
# 2                                Red Hood  Arnold, Elana K.
# 3                     The Handmaid's Tale  Atwood, Margaret
# 4  The Handmaid's Tale: The Graphic Novel  Atwood, Margaret
#
#   Secondary Author(s) Illustrator(s) Translator(s)           Series Name  \
# 0                 NaN            NaN           NaN  Call Me By Your Name
# 1                 NaN            NaN           NaN                   NaN
# 2                 NaN            NaN           NaN                   NaN
# 3                 NaN            NaN           NaN                   NaN
# 4                 NaN   Nault, Renee           NaN                   NaN
#
#     State                                   District  \
# 0  Alaska  Matanuska-Susitna Borough School District
# 1  Alaska  Matanuska-Susitna Borough School District
# ...

# %%
df_2024_State.shape
# Out:
# (10046, 11)

# %%
df_2024_State['Title'].value_counts()
# Out:
# Title
# Nineteen Minutes                                      98
# Looking for Alaska                                    97
# The Perks of Being a Wallflower                       85
# Sold                                                  85
# Crank                                                 76
#                                                       ..
# Warcross                                               1
# Wildcard                                               1
# Blood of my Blood                                      1
# The Astonishing Adventures of Fanboy and Goth Girl     1
# Last Man: The Royal Cup                                1
# Name: count, Length: 4239, dtype: int64

# %%
df_2024_State['Title'].value_counts().head(10)
# Out:
# Title
# Nineteen Minutes                   98
# Looking for Alaska                 97
# The Perks of Being a Wallflower    85
# Sold                               85
# Crank                              76
# Thirteen Reasons Why               76
# Identical                          74
# The Kite Runner                    73
# The Handmaid's Tale                67
# Water for Elephants                66
# Name: count, dtype: int64

# %%
# 1. Nineteen Minutes: Sexual Content/Abuse, LGBTQ+ Content, Violence/Racism Concerns       
# 2. Looking for Alaska: Sexual Content/Abuse, Substance Use/Abuse, Mental Illness              
# 3. The Perks of Being a Wallflower: Sexual Content/Abuse, LGBTQ+ Content, Substance Use/Abuse, Mental Illness 
# 4. Sold: Sexual Content/Abuse, Violence/Racism Concerns                                 
# 5. Crank: Substance Use/Abuse, Sexual Content/Abuse                               
# 6. Thirteen Reasons Why: Sexual Content/Abuse, Mental Illness, Substance Use/Abuse               
# 7. Identical: Sexual Content/Abuse, Mental Illness, Substance Use/Abuse                          
# 8. The Kite Runner: Sexual Content/Abuse, Violence/Racism Concerns                     
# 9. The Handmaid's Tale: Sexual Content/Abuse, Violence/Racism Concerns               
# 10. Water for Elephants: Sexual Content/Abuse

# %%
df_2024_State['State'].value_counts()
# Out:
# State
# Florida           4561
# Iowa              3671
# Texas              538
# Wisconsin          408
# Virginia           121
# Kentucky           100
# Georgia             83
# Maine               83
# South Carolina      64
# Maryland            64
# North Carolina      61
# Missouri            57
# Alaska              56
# Wyoming             42
# Tennessee           34
# Utah                32
# Pennsylvania        20
# Oregon              18
# Idaho               12
# New York             6
# Montana              3
# Ohio                 3
# California           2
# Illinois             2
# Minnesota            1
# New Jersey           1
# Massachusetts        1
# Louisiana            1
# Indiana              1
# Name: count, dtype: int64

# %%
df_2024_Author = pd.read_excel("2023-2024.xlsx", sheet_name="Sorted by Author & Title")
df_2024_Author.head()
# Out:
#                                             Title              Author  \
# 0                                     Next Summer      Abbott, Hailey
# 1                                    Summer Girls      Abbott, Hailey
# 2  In the Belly of the Beast: Letters From Prison  Abbott, Jack Henry
# 3                           The End of Everything       Abbott, Megan
# 4                         The Summer of Owen Todd        Abbott, Tony
#
#   Secondary Author(s) Illustrator(s) Translator(s)   Series Name    State  \
# 0                 NaN            NaN           NaN  Summer Girls  Florida
# 1                 NaN            NaN           NaN  Summer Girls  Florida
# 2                 NaN            NaN           NaN           NaN  Florida
# 3                 NaN            NaN           NaN           NaN  Florida
# 4                 NaN            NaN           NaN           NaN  Florida
#
#                          District Date of Challenge/Removal  \
# ...

# %%
df_2024_Author.shape
# Out:
# (10046, 11)

# %%
df_2024_Author['Author'].value_counts()
# Out:
# Author
# Hopkins, Ellen       523
# Maas, Sarah J.       481
# King, Stephen        173
# Picoult, Jodi        161
# Green, John          157
#                     ...
# Mabry, Samantha        1
# Maberry, Jonathan      1
# Dapier, Jarrett        1
# Lyons, Mary E.         1
# Kraft, Vickie          1
# Name: count, Length: 2411, dtype: int64

# %%
df_2024_Author['State'].value_counts()
# Out:
# State
# Florida           4561
# Iowa              3671
# Texas              538
# Wisconsin          408
# Virginia           121
# Kentucky           100
# Georgia             83
# Maine               83
# Maryland            64
# South Carolina      64
# North Carolina      61
# Missouri            57
# Alaska              56
# Wyoming             42
# Tennessee           34
# Utah                32
# Pennsylvania        20
# Oregon              18
# Idaho               12
# New York             6
# Ohio                 3
# Montana              3
# Illinois             2
# California           2
# Massachusetts        1
# Louisiana            1
# New Jersey           1
# Minnesota            1
# Indiana              1
# Name: count, dtype: int64

# %% [markdown]
# # 2022-2023:

# %%
df_2023_State = pd.read_excel("2022-2023.xlsx", sheet_name="Sorted by State & District")
df_2023_State.head()
# Out:
#                            Title         Author Secondary Author(s)  \
# 0                        #Hockey   Ukazu, Ngozi                 NaN
# 1                        #Hockey   Ukazu, Ngozi                 NaN
# 2  10 Things I Can See from Here    Mac, Carrie                 NaN
# 3                 10,000 Dresses  Ewert, Marcus                 NaN
# 4                 10,000 Dresses  Ewert, Marcus                 NaN
#
#   Illustrator(s) Translator(s)     Series Name    State  \
# 0            NaN           NaN  Check, Please!    Texas
# 1            NaN           NaN  Check, Please!  Florida
# 2            NaN           NaN             NaN  Florida
# 3       Ray, Rex           NaN             NaN  Florida
# 4       Ray, Rex           NaN             NaN  Florida
#
#                              District Date of Challenge/Removal  \
# 0  Frisco Independent School District       2022-11-01 00:00:00
# 1         Clay County School District              AY 2022-2023
# ...

# %%
df_2023_State.shape
# Out:
# (3362, 11)

# %%
df_2023_State['Title'].value_counts()
# Out:
# Title
# Tricks                              33
# The Bluest Eye                      29
# A Court of Mist and Fury            27
# Looking for Alaska                  27
# Gender Queer: A Memoir              26
#                                     ..
# If I Stay                            1
# Ida and Jake's Game Night            1
# Ida and Jake Versus Mister Plant     1
# Ida and Jake Save the Parade         1
# Zombies Don't Cry                    1
# Name: count, Length: 1557, dtype: int64

# %%
df_2023_State['Title'].value_counts().head(10)
# Out:
# Title
# Tricks                             33
# The Bluest Eye                     29
# A Court of Mist and Fury           27
# Looking for Alaska                 27
# Gender Queer: A Memoir             26
# The Perks of Being a Wallflower    25
# Sold                               24
# Thirteen Reasons Why               24
# Crank                              23
# Empire of Storms                   22
# Name: count, dtype: int64

# %%
# 1. Tricks: Sexual Content/Abuse, Substance Use/Abuse, LGBTQ+ Content
# 2. The Bluest Eye: Sexual Content/Abuse, Violence/Racism Concerns
# 3. A Court of Mist and Fury: Sexual Content/Abuse
# 4. Looking for Alaska: Sexual Content/Abuse, Substance Use/Abuse, Mental Illness
# 5. Gender Queer: A Memoir: Sexual Content/Abuse, LGBTQ+ Content
# 6. The Perks of Being a Wallflower: Sexual Content/Abuse, LGBTQ+ Content, Substance Use/Abuse, Mental Illness
# 7. Sold: Sexual Content/Abuse, Violence Concerns
# 8. Thirteen Reasons Why: Sexual Content/Abuse, Mental Illness, Substance Use/Abuse
# 9. Crank: Substance Use/Abuse, Sexual Content/Abuse
# 10. Empire of Storms: Sexual Content/Abuse

# %%
df_2023_State['State'].value_counts()
# Out:
# State
# Florida           1406
# Texas              624
# Missouri           333
# Utah               281
# Pennsylvania       186
# South Carolina     127
# Virginia            75
# North Carolina      58
# Wisconsin           43
# Michigan            39
# Oregon              38
# North Dakota        27
# Idaho               25
# Wyoming             15
# Maine               13
# Tennessee           11
# Colorado             8
# Kansas               7
# New York             6
# Nebraska             6
# Iowa                 6
# Arkansas             4
# Georgia              4
# New Jersey           3
# Kentucky             3
# Indiana              3
# South Dakota         2
# Oklahoma             2
# West Virginia        2
# Minnesota            1
# New Hampshire        1
# Massachusetts        1
# California           1
# State                1
# Name: count, dtype: int64

# %%
df_2023_Author = pd.read_excel("2022-2023.xlsx", sheet_name="Sorted by Author & Title")
df_2023_Author.head()
# Out:
#                                                Title                  Author  \
# 0  Liar, Temptress, Soldier, Spy: Four Women Unde...           Abbott, Karen
# 1                                      Ace of Spades  Àbíké-Íyímídé, Faridah
# 2                                      Ace of Spades  Àbíké-Íyímídé, Faridah
# 3                                      Ace of Spades  Àbíké-Íyímídé, Faridah
# 4                                      Ace of Spades  Àbíké-Íyímídé, Faridah
#
#   Secondary Author(s) Illustrator(s) Translator(s) Series Name    State  \
# 0                 NaN            NaN           NaN         NaN    Texas
# 1                 NaN            NaN           NaN         NaN  Florida
# 2                 NaN            NaN           NaN         NaN  Florida
# 3                 NaN            NaN           NaN         NaN  Florida
# 4                 NaN            NaN           NaN         NaN  Florida
#
#                              District Date of Challenge/Removal  \
# ...

# %%
df_2023_Author.shape
# Out:
# (3362, 11)

# %%
df_2023_Author['Author'].value_counts()
# Out:
# Author
# Hopkins, Ellen         225
# Maas, Sarah J.         158
# Matsui, Yūsei           56
# Atwood, Margaret        52
# Arnold, Elana K.        51
#                       ...
# Hoffman, Sarah           1
# Hollingsworth, Mary      1
# Homer                    1
# Hopkins, Suzy            1
# Langford, Jo             1
# Name: count, Length: 988, dtype: int64

# %%
df_2023_Author['State'].value_counts()
# Out:
# State
# Florida           1406
# Texas              625
# Missouri           333
# Utah               281
# Pennsylvania       186
# South Carolina     127
# Virginia            75
# North Carolina      58
# Wisconsin           43
# Michigan            39
# Oregon              38
# North Dakota        27
# Idaho               25
# Wyoming             15
# Maine               13
# Tennessee           11
# Colorado             8
# Kansas               7
# New York             6
# Nebraska             6
# Iowa                 6
# Arkansas             4
# Georgia              4
# New Jersey           3
# Kentucky             3
# Indiana              3
# Oklahoma             2
# South Dakota         2
# West Virginia        2
# California           1
# Massachusetts        1
# New Hampshire        1
# Minnesota            1
# Name: count, dtype: int64

# %% [markdown]
# # 2021-2022:

# %%
df_2022_State = pd.read_excel("2021-2022.xlsx", sheet_name="Sorted by State & District")
df_2022_State.head()
# Out:
#                                                Title          Author  \
# 0                             Gender Queer: A Memoir    Kobabe, Maia
# 1        Beyond Magenta: Transgender Teens Speak Out   Kuklin, Susan
# 2  A Court of Frost and Starlight (A Court of Tho...  Maas, Sarah J.
# 3  A Court of Mist and Fury (A Court of Thorns an...  Maas, Sarah J.
# 4  A ​Court of Silver Flames (A Court of Thorns a...  Maas, Sarah J.
#
#   Secondary Author(s) Illustrator(s) Translator(s)     State  \
# 0                 NaN            NaN           NaN    Alaska
# 1                 NaN            NaN           NaN  Arkansas
# 2                 NaN            NaN           NaN   Florida
# 3                 NaN            NaN           NaN   Florida
# 4                 NaN            NaN           NaN   Florida
#
#                          District Origin of Challenge  \
# 0       Anchorage School District       Administrator
# 1  Siloam Springs School District    Formal Challenge
# ...

# %%
df_2022_State.shape
# Out:
# (2532, 10)

# %%
df_2022_State['State'].value_counts()
# Out:
# State
# Texas             801
# Florida           566
# Pennsylvania      458
# Tennessee         349
# Oklahoma           43
# Michigan           41
# Kansas             30
# Wisconsin          29
# Missouri           27
# Idaho              26
# Georgia            23
# Mississippi        22
# Virginia           19
# Indiana            18
# North Carolina     16
# New York           13
# Utah               12
# Iowa                8
# South Dakota        5
# Illinois            5
# Washington          5
# Ohio                4
# New Jersey          3
# Arkansas            1
# Minnesota           1
# Oregon              1
# Maryland            1
# Rhode Island        1
# South Carolina      1
# Maine               1
# Vermont             1
# Alaska              1
# Name: count, dtype: int64

# %%
df_2022_State['Title'].value_counts()
# Out:
# Title
# Gender Queer: A Memoir                                                     41
# All Boys Aren't Blue                                                       29
# Out of Darkness                                                            24
# The Bluest Eye                                                             22
# Lawn Boy                                                                   17
#                                                                            ..
# Last Stop on Market Street                                                  1
# Knock Knock: My Dad's Dream for Me                                          1
# King & Kayla and the Case of the Unhappy Neighbor (King & Kayla Series)     1
# King & Kayla and the Case of the Secret Code (King & Kayla Series)          1
# Let it Snow: Three Holiday Romances                                         1
# Name: count, Length: 1648, dtype: int64

# %%
df_2022_State['Title'].value_counts().head(10)
# Out:
# Title
# Gender Queer: A Memoir                             41
# All Boys Aren't Blue                               29
# Out of Darkness                                    24
# The Bluest Eye                                     22
# Lawn Boy                                           17
# The Hate U Give                                    17
# The Absolutely True Diary of a Part-Time Indian    16
# Me and Earl and the Dying Girl                     14
# Thirteen Reasons Why                               12
# l8r, g8r                                           12
# Name: count, dtype: int64

# %%
# 1. Gender Queer: A Memoir: Sexual Content/Abuse, LGBTQ+ Content
# 2. All Boys Aren't Blue: Sexual Content/Abuse, LGBTQ+ Content
# 3. Out of Darkness: Sexual Content/Abuse, Violence/Racism Concerns
# 4. The Bluest Eye: Sexual Content/Abuse, Violence/Racism Concerns
# 5. Lawn Boy: Sexual Content/Abuse, LGBTQ+ Content
# 6. The Hate U Give: Violence/Racism Concerns
# 7. The Absolutely True Diary of a Part-Time Indian: Sexual Content/Abuse, Violence/Racism Concerns
# 8. Me and Earl and the Dying Girl: Sexual Content/Abuse
# 9. Thirteen Reasons Why: Sexual Content/Abuse, Mental Illness, Substance Use/Abuse
# 10. l8r, g8r: Sexual Content/Abuse, Violence/Racism Concerns

# %%
df_2022_Author = pd.read_excel("2021-2022.xlsx", sheet_name="Sorted by Author & Title")
df_2022_Author.head()
# Out:
#                 Title                  Author Secondary Author(s)  \
# 0       Ace of Spades  Àbíké-Íyímídé, Faridah                 NaN
# 1  Clap When You Land      Acevedo, Elizabeth                 NaN
# 2          The Poet X      Acevedo, Elizabeth                 NaN
# 3          The Poet X      Acevedo, Elizabeth                 NaN
# 4          The Poet X      Acevedo, Elizabeth                 NaN
#
#   Illustrator(s) Translator(s)         State  \
# 0            NaN           NaN       Florida
# 1            NaN           NaN  Pennsylvania
# 2            NaN           NaN       Florida
# 3            NaN           NaN      New York
# 4            NaN           NaN         Texas
#
#                                      District Date of Challenge/Removal  \
# 0         Indian River County School District                2021-11-01
# 1                Central York School District                2021-08-31
# 2         Indian River County School District                2021-11-01
# ...

# %%
df_2022_Author.shape
# Out:
# (2532, 10)

# %%
df_2022_Author['Author'].value_counts()
# Out:
# Author
# Hopkins, Ellen          43
# Kobabe, Maia            41
# Morrison, Toni          34
# Johnson, George M.      30
# Myracle, Lauren         29
#                         ..
# Hurston, Zora Neale      1
# Hurwin, Davida Wills     1
# Hyde, Catherine Ryan     1
# Hyman, Miles             1
# Zunon, Elizabeth         1
# Name: count, Length: 1149, dtype: int64

# %%
# Create a dataframe for value counts of the 'State' column
state_counts = df_2024_State['State'].value_counts().reset_index()
state_counts = df_2023_State['State'].value_counts().reset_index()
state_counts = df_2022_State['State'].value_counts().reset_index()

# Step 2: Get the value counts for the 'State' column for each year
state_counts_2024 = df_2024_State['State'].value_counts().reset_index()
state_counts_2023 = df_2023_State['State'].value_counts().reset_index()
state_counts_2022 = df_2022_State['State'].value_counts().reset_index()

# Step 3: Rename columns for clarity
state_counts_2024.columns = ['State', '2024 Count']
state_counts_2023.columns = ['State', '2023 Count']
state_counts_2022.columns = ['State', '2022 Count']

# Step 4: Merge the dataframes for all three years
state_counts_three_years = state_counts_2022.merge(state_counts_2023, on='State', how='outer') \
                                           .merge(state_counts_2024, on='State', how='outer')
# how='outer' ensures that all states are included, even if some states are missing in a particular year.

state_counts_three_years['2024 Count'] = state_counts_three_years['2024 Count'].fillna(0).astype(int)
state_counts_three_years['2023 Count'] = state_counts_three_years['2023 Count'].fillna(0).astype(int)
state_counts_three_years['2022 Count'] = state_counts_three_years['2022 Count'].fillna(0).astype(int)

save_path = '/Users/yushuowang/Desktop/1Columbia/Data Journalism/Data Studio/Data-driven Pitches/Book Ban/state_counts_three_years.xlsx'
state_counts_three_years.to_excel(save_path, index=False)

# %%
state_counts_three_years
# Out:
#              State  2022 Count  2023 Count  2024 Count
# 0           Alaska           1           0          56
# 1         Arkansas           1           4           0
# 2       California           0           1           2
# 3         Colorado           0           8           0
# 4          Florida         566        1406        4561
# 5          Georgia          23           4          83
# 6            Idaho          26          25          12
# 7         Illinois           5           0           2
# 8          Indiana          18           3           1
# 9             Iowa           8           6        3671
# 10          Kansas          30           7           0
# 11        Kentucky           0           3         100
# 12       Louisiana           0           0           1
# 13           Maine           1          13          83
# 14        Maryland           1           0          64
# 15   Massachusetts           0           1           1
# ...

# %% [markdown]
# # Book Ban Over Three Years:

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%R
#
# install.packages("ggpattern")
# Out:
# --- Please select a CRAN mirror for use in this session ---
# Secure CRAN mirrors
#
#  1: 0-Cloud [https]
#  2: Australia (Canberra) [https]
#  3: Australia (Melbourne 1) [https]
#  4: Australia (Melbourne 2) [https]
#  5: Austria (Wien 1) [https]
#  6: Belgium (Brussels) [https]
#  7: Brazil (PR) [https]
#  8: Brazil (SP 1) [https]
#  9: Brazil (SP 2) [https]
# 10: Bulgaria [https]
# 11: Canada (MB) [https]
# 12: Canada (ON 1) [https]
# 13: Canada (ON 2) [https]
# 14: Chile (Santiago) [https]
# 15: China (Beijing 2) [https]
# 16: China (Beijing 3) [https]
# 17: China (Hefei) [https]
# 18: China (Hong Kong) [https]
# 19: China (Jinan) [https]
# 20: China (Lanzhou) [https]
# 21: China (Nanjing) [https]
# 22: China (Shanghai 2) [https]
# 23: China (Shenzhen) [https]
# 24: China (Wuhan) [https]
# 25: Colombia (Cali) [https]
# 26: Costa Rica [https]
# 27: Cyprus [https]
# 28: Czech Republic [https]
# 29: Denmark [https]
# 30: East Asia [https]
# 31: Ecuador (Cuenca) [https]
# ...

# %%
# %%R
# install.packages("magick")
# Out:
# The downloaded binary packages are in
# 	/var/folders/34/r81f149n4fs8wyktjp9qbm8w0000gn/T//RtmpNytYqU/downloaded_packages
# trying URL 'https://repo.miserver.it.umich.edu/cran/bin/macosx/big-sur-arm64/contrib/4.4/magick_2.8.5.tgz'
# Content type 'application/octet-stream' length 21646291 bytes (20.6 MB)
# ...
# downloaded 20.6 MB

# %%
# %%R
# require('tidyverse')
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: tidyverse

# %%
# %%R
# library(ggplot2)
# library(readr)
# library(ggpattern)
# library(magick)
# Out:
# Linking to ImageMagick 6.9.12.93
# Enabled features: cairo, fontconfig, freetype, heic, lcms, pango, raw, rsvg, webp
# Disabled features: fftw, ghostscript, x11

# %%
# %%R
#
# # Set up workspace
# setwd('/Users/yushuowang/Desktop/1Columbia/Data Journalism/Data Studio/Data-driven Pitches/Book Ban/Graphics')
#
# # Create data frame
# Book_Ban_Instance <- data.frame(
#   year = c("2021-2022", "2022-2023", "2023-2024"),
#   instances = c(2352, 3362, 10046),
#   titles = c(1648, 1557, 4231),
#   image = c("Book Stack 12.png", "Book Stack 12.png", "Book Stack 12.png")
# )
#
# Book_Ban_Instance
# Out:
#        year instances titles             image
#  2021-2022      2352   1648 Book Stack 12.png
#  2022-2023      3362   1557 Book Stack 12.png
#  2023-2024     10046   4231 Book Stack 12.png

# %%
# %%R -w 2000 -h 600
#
# # Set up workspace
# setwd('/Users/yushuowang/Desktop/1Columbia/Data Journalism/Data Studio/Data-driven Pitches/Book Ban/Graphics')
#
# # Create data frame
# Book_Ban_Instance <- data.frame(
#   year = c("2021-2022", "2022-2023", "2023-2024"),
#   instances = c(2352, 3362, 10046),
#   titles = c(1648, 1557, 4231),
#   image = c("Book Stack 12.png", "Book Stack 12.png", "Book Stack 12.png")
# )
#
# # Pivot Longer Data
# Book_Ban_Instance_long <- Book_Ban_Instance %>%
#   pivot_longer(cols = c(instances, titles),
#                names_to = "type",
#                values_to = "count")
#
# Book_Ban_Instance_long
# Out:
# # A tibble: 6 × 4
#   year      image             type      count
#   <chr>     <chr>             <chr>     <dbl>
# 1 2021-2022 Book Stack 12.png instances  2352
# 2 2021-2022 Book Stack 12.png titles     1648
# 3 2022-2023 Book Stack 12.png instances  3362
# 4 2022-2023 Book Stack 12.png titles     1557
# 5 2023-2024 Book Stack 12.png instances 10046
# 6 2023-2024 Book Stack 12.png titles     4231

# %% [markdown]
# # Create a Treemap on Subject Matter:

# %%
# %%R
# install.packages("treemapify")
# Out:
# The downloaded binary packages are in
# 	/var/folders/34/r81f149n4fs8wyktjp9qbm8w0000gn/T//RtmpNytYqU/downloaded_packages
# trying URL 'https://repo.miserver.it.umich.edu/cran/bin/macosx/big-sur-arm64/contrib/4.4/treemapify_2.5.6.tgz'
# Content type 'application/octet-stream' length 557228 bytes (544 KB)
# ...
# downloaded 544 KB

# %%
# %%R -w 800 -h 500
#
# library(ggplot2)
# library(treemapify)
#
# # Data for the top-10 banned books for three time periods (total 30 entries)
# reasons_list <- c(
#   # 2023-2024
#   "Sexual Content/Abuse, LGBTQ+ Content, Violence/Racism Concerns",
#   "Sexual Content/Abuse, Substance Use/Abuse, Mental Illness",
#   "Sexual Content/Abuse, LGBTQ+ Content, Substance Use/Abuse, Mental Illness",
#   "Sexual Content/Abuse, Violence/Racism Concerns",
#   "Substance Use/Abuse, Sexual Content/Abuse",
#   "Sexual Content/Abuse, Mental Illness, Substance Use/Abuse",
#   "Sexual Content/Abuse, Mental Illness, Substance Use/Abuse",
#   "Sexual Content/Abuse, Violence/Racism Concerns",
#   "Sexual Content/Abuse, Violence/Racism Concerns",
#   "Sexual Content/Abuse",
#   # 2022-2023
#   "Sexual Content/Abuse, Substance Use/Abuse, LGBTQ+ Content",
#   "Sexual Content/Abuse, Violence/Racism Concerns",
#   "Sexual Content/Abuse",
#   "Sexual Content/Abuse, Substance Use/Abuse, Mental Illness",
#   "Sexual Content/Abuse, LGBTQ+ Content",
#   "Sexual Content/Abuse, LGBTQ+ Content, Substance Use/Abuse, Mental Illness",
#   "Sexual Content/Abuse, Violence/Racism Concerns",
#   "Sexual Content/Abuse, Mental Illness, Substance Use/Abuse",
#   "Substance Use/Abuse, Sexual Content/Abuse",
#   "Sexual Content/Abuse",
#   # 2021-2022
#   "Sexual Content/Abuse, LGBTQ+ Content",
#   "Sexual Content/Abuse, LGBTQ+ Content",
#   "Sexual Content/Abuse, Violence/Racism Concerns",
#   "Sexual Content/Abuse, Violence/Racism Concerns",
#   "Sexual Content/Abuse, LGBTQ+ Content",
#   "Violence/Racism Concerns",
#   "Sexual Content/Abuse, Violence/Racism Concerns",
#   "Sexual Content/Abuse",
#   "Sexual Content/Abuse, Mental Illness, Substance Use/Abuse",
#   "Sexual Content/Abuse, Violence/Racism Concerns"
# )

# %%
# %%R -w 800 -h 500
#
# # Parse the banned reasons: split each string by comma and trim whitespace.
# all_reasons <- unlist(strsplit(reasons_list, ","))
# all_reasons <- trimws(all_reasons)
#
# # Create a data frame for counting
# df_reasons <- data.frame(Reason = all_reasons)
#
# # Count each banned reason
# reason_counts <- as.data.frame(table(df_reasons$Reason))
#
# # Prepare labels and sizes for the treemap
# labels <- paste(reason_counts$Var1, "\n(", reason_counts$Freq, ")", sep="")
# sizes <- reason_counts$Freq

# %%
# %%R -w 860 -h 600
#
# # Define custom colors
# customized_colors_2 <- c(
#   "#A69E91", # Sandstone Beige
#   "#5C6A6B", # Slate Gray
#   "#A85E59", # Warm Coral
#   "#B18F88", # Soft Cinnamon
#   "#6A7F7D", # Dusty Teal
#   "#537D6D", # Forest Green
#   "#9A8D99", # Pale Lavender
#   "#839B7A", # Olive Drab
#   "#BFA59B", # Taupe Brown
#   "#6E6B7E"  # Slate Blue
# )
#
# # Create a proportional font size scale
# min_font_size <- 20
# max_font_size <- 30
#
# # Normalize sizes to create proportional font sizes
# max_size <- max(sizes)
# min_size <- min(sizes)
# scaled_font_sizes <- (min_font_size + (max_font_size - min_font_size) * (sizes - min_size) / (max_size - min_size))
#
# # Create a treemap plot using ggplot2 and treemapify
# treemap <- ggplot(reason_counts) +
#   aes(area = sizes, fill = Var1, label = labels, subgroup = Var1) +
#   geom_treemap(color = "white", size = 0.5, radius = unit(5, "pt")) +
#   geom_treemap_subgroup_text(
#     place = "topleft",
#     color = "white",
#     family = "Georgia",
#     fontface = "bold",
#     size = scaled_font_sizes  # Adjust the label size based on the frequency/size
#   ) +
#   scale_fill_manual(values = customized_colors_2) +
#   labs(
#     title = "Many more books removed from shelves over sexual content and abuse themes",
#     # subtitle = "Subject matter of top ten banned book titles from 2021 to 2024",
#     caption = "Data source: PEN America | Treemap: Yushuo Wang",
#     fill = "Reason"
#   ) +
#   theme_minimal() +
#   theme(
#     legend.position = "none",
#     text = element_text(family = "Georgia"),
#     plot.title = element_text(size = 22, hjust = 0, color = "black", face = "bold", family = "Arial"),
#     plot.subtitle = element_text(size = 18, hjust = 0, color = "black", family = "Arial"),
#     plot.caption = element_text(size = 18, hjust = 0, color = "black", family = "Arial"),
#     plot.background = element_rect(fill = "white", color = NA),
#     panel.background = element_rect(fill = "white", color = NA)
#   )
#
# # Show the treemap
# treemap

# %%
# %%R
# # Save the treemap
# ggsave("/Users/yushuowang/Desktop/1Columbia/Data Journalism/Data Studio/Data-driven Pitches/Book Ban/treemap.png",
#        plot = treemap,
#        width = 860 / 72,
#        height = 600 / 72,
#        dpi = 300)

# %%
# %%R
# install.packages("svglite")
# Out:
# The downloaded binary packages are in
# 	/var/folders/34/r81f149n4fs8wyktjp9qbm8w0000gn/T//RtmpNytYqU/downloaded_packages
# trying URL 'https://repo.miserver.it.umich.edu/cran/bin/macosx/big-sur-arm64/contrib/4.4/svglite_2.1.3.tgz'
# Content type 'application/octet-stream' length 888575 bytes (867 KB)
# ...
# downloaded 867 KB

# %%
# %%R
# ggsave("/Users/yushuowang/Desktop/1Columbia/Data Journalism/Data Studio/Data-driven Pitches/Book Ban/treemap.svg",
#        plot = treemap,
#        width = 860 / 72,
#        height = 600 / 72,
#        device = svglite::svglite)

# %% [markdown]
# # Ignore Codes Below:

# %%
# Install package for creating tree map
# !pip install squarify

# %%
import matplotlib.pyplot as plt
import squarify  

# Data for the top-10 banned books for three time periods (total 30 entries)
# For each entry, list the banned reasons as given:
reasons_list = [
    # 2023-2024
    "Sexual Content/Abuse, LGBTQ+ Content, Violence/Racism Concerns",
    "Sexual Content/Abuse, Substance Use/Abuse, Mental Illness",
    "Sexual Content/Abuse, LGBTQ+ Content, Substance Use/Abuse, Mental Illness",
    "Sexual Content/Abuse, Violence/Racism Concerns",
    "Substance Use/Abuse, Sexual Content/Abuse",
    "Sexual Content/Abuse, Mental Illness, Substance Use/Abuse",
    "Sexual Content/Abuse, Mental Illness, Substance Use/Abuse",
    "Sexual Content/Abuse, Violence/Racism Concerns",
    "Sexual Content/Abuse, Violence/Racism Concerns",
    "Sexual Content/Abuse",
    # 2022-2023
    "Sexual Content/Abuse, Substance Use/Abuse, LGBTQ+ Content",
    "Sexual Content/Abuse, Violence/Racism Concerns",
    "Sexual Content/Abuse",
    "Sexual Content/Abuse, Substance Use/Abuse, Mental Illness",
    "Sexual Content/Abuse, LGBTQ+ Content",
    "Sexual Content/Abuse, LGBTQ+ Content, Substance Use/Abuse, Mental Illness",
    "Sexual Content/Abuse, Violence/Racism Concerns",
    "Sexual Content/Abuse, Mental Illness, Substance Use/Abuse",
    "Substance Use/Abuse, Sexual Content/Abuse",
    "Sexual Content/Abuse",
    # 2021-2022
    "Sexual Content/Abuse, LGBTQ+ Content",
    "Sexual Content/Abuse, LGBTQ+ Content",
    "Sexual Content/Abuse, Violence/Racism Concerns",
    "Sexual Content/Abuse, Violence/Racism Concerns",
    "Sexual Content/Abuse, LGBTQ+ Content",
    "Violence/Racism Concerns",
    "Sexual Content/Abuse, Violence/Racism Concerns",
    "Sexual Content/Abuse",
    "Sexual Content/Abuse, Mental Illness, Substance Use/Abuse",
    "Sexual Content/Abuse, Violence/Racism Concerns"
]

# Parse the banned reasons: split each string by comma and trim whitespace.
all_reasons = []
for reason_str in reasons_list:
    # Split by comma and strip whitespace from each sub-reason
    parts = [r.strip() for r in reason_str.split(',')]
    all_reasons.extend(parts)

# Create a DataFrame for counting
df_reasons = pd.DataFrame(all_reasons, columns=["Reason"]) # "Reason" as column name

# Count each unique reason
reason_counts = df_reasons["Reason"].value_counts()

# Prepare labels and sizes for the treemap
labels = [f"{k}\n({v})" for k, v in reason_counts.items()] # .items() returns pairs of (key, value)
sizes = reason_counts.values # .values gives the 

# Create a treemap plot using squarify
plt.figure(figsize=(12, 8))
# Plot the treemap
ax = squarify.plot(sizes=sizes, label=labels, alpha=.8, color=plt.cm.Paired(range(len(sizes))))

# Define a font size scale
min_font_size = 12
max_font_size = 18 

# Normalize sizes to create proportional font sizes
max_size = max(sizes)
min_size = min(sizes)
scaled_font_sizes = [(min_font_size + (max_font_size - min_font_size) * (size - min_size) / (max_size - min_size)) for size in sizes]

# Adjust the font size of the labels based on the rectangle size
for i, text in enumerate(ax.texts):  # Iterate over label text objects
    text.set_fontsize(scaled_font_sizes[i])  # Set the scaled font size for each label


# Set the title and subtitle on the same line, aligned to the left
plt.title("Many more books removed from shelves over sexual content and abuse themes", fontsize=19, loc='left',fontweight='light', fontname='Arial')

# Adjust layout to reduce space between title/subtitle and plot
plt.subplots_adjust(top=0.9, bottom=0.07)  # Adjust 'top' to reduce space above the plot

# Add the data source as a caption, left-aligned and correctly spaced
plt.figtext(0.124, 0.02, "Subject matter of top ten banned book titles from 2021 to 2024\nData source: PEN America, by Yushuo Wang", ha="left", fontsize=12, fontname='Arial')

plt.axis('off')
plt.show()

# %%
# %%R -w 2000 -h 600
#
# # Set up workspace
# setwd('/Users/wangyushuo/Desktop/1Columbia/Data Journalism/Data Studio/Data-driven Pitches/Book Ban/Graphics')
#
# # Create data frame
# Book_Ban_Instance <- data.frame(
#   year = c("2021-2022", "2022-2023", "2023-2024"),
#   instances = c(2352, 3362, 10046),
#   titles = c(1648, 1557, 4231),
#   image = c("Book Stack 12.png", "Book Stack 12.png", "Book Stack 12.png")
# )
#
# # Pivot Longer Data
# Book_Ban_Instance_long <- Book_Ban_Instance %>%
#   pivot_longer(cols = c(instances, titles),
#                names_to = "type",
#                values_to = "count")
#
#
# # Generate the plot with an instance and a title column each year
# ggplot(Book_Ban_Instance_long) +
#   aes(x = count, y = factor(year), fill = type) +
#   geom_col_pattern(
#     aes(pattern_filename = image),
#     pattern = 'image',
#     pattern_fill = "white",
#     fill = 'white',
#     pattern_type = 'expand',
#     pattern_aspect_ratio = 1
#   ) +
#   scale_pattern_filename_discrete(choices = Book_Ban_Instance$image) +
#   geom_text(aes(label = paste0(count)), hjust = -1, size = 6.2) +
#   coord_cartesian(xlim = c(0, 12000)) +
#   facet_grid(year ~ type, scales = "free_y", space = "free_y") +
#   theme_minimal() +
#   theme(
#     text = element_text(size = 30),
#     axis.text.x = element_text(size = 16, hjust = 1),
#     axis.text.y = element_text(size = 16, hjust = 1),
#     strip.text.y = element_blank(),  # Remove facet labels
#     panel.grid.major = element_blank(),  # Remove major grid lines
#     panel.grid.minor = element_blank(),  # Remove minor grid lines
#     plot.caption = element_text(size = 16, hjust = 0, vjust = -1),
#     plot.margin = margin(10, 10, 20, 10)
#   ) +
#   labs(
#     title = "Book Ban Instances Surge over the past Three Years",
#     subtitle = "Instances of Book Ban and Number of Book Titles Banned",
#     x = NULL,
#     y = NULL,
#     caption = "Data source: PEN America"
#   ) +
#   theme(legend.position = "none") +
#   # Set x-axis breaks to every 2000
#   scale_x_continuous(breaks = seq(0, 12000, by = 2000))  # Set breaks every 2000 units

# %%
# %%R -w 2000 -h 600
#
# # Set up workspace
# setwd('/Users/wangyushuo/Desktop/1Columbia/Data Journalism/Data Studio/Data-driven Pitches/Book Ban/Graphics')
#
# # Create data frame
# Book_Ban_Instance <- data.frame(
#   year = c("2021-2022", "2022-2023", "2023-2024"),
#   instances = c(2352, 3362, 10046),
#   titles = c(1648, 1557, 4231),
#   image_instances = c("resized_image_2.png", "resized_image_3.png", "resized_image_1.png"),  # These images for instances
#   image_titles = c("resized_for_titles_3.png", "resized_for_titles_2.png", "resized_for_titles_1.png")  # These images for banned titles
# )
#
# # Pivot Longer Data
# Book_Ban_Instance_long <- Book_Ban_Instance %>%
#   pivot_longer(cols = c(instances, titles),
#                names_to = "type",
#                values_to = "count")
#
# # Add the correct images based on the type (instances or titles)
# Book_Ban_Instance_long$image <- ifelse(Book_Ban_Instance_long$type == "instances",
#                                         rep(Book_Ban_Instance$image_instances, each = 1),
#                                         rep(Book_Ban_Instance$image_titles, each = 1))
#
# # Generate the plot with an instance and a title column each year
# ggplot(Book_Ban_Instance_long) +
#   aes(x = count, y = factor(year), fill = type) +
#   geom_col_pattern(
#     aes(pattern_filename = image),
#     pattern = 'image',
#     pattern_fill = "white",
#     fill = 'white',
#     pattern_type = 'image',  # Ensures image is used directly without resizing
#     pattern_ratio = 1        # Ensures the image aspect ratio is preserved
#   ) +
#   scale_pattern_filename_discrete(choices = Book_Ban_Instance_long$image) +
#   geom_text(aes(label = paste0(count)), hjust = -1, size = 6.2) +
#   coord_cartesian(xlim = c(0, 12000)) +
#   facet_grid(year ~ type, scales = "free_y", space = "free_y") +
#   theme_minimal() +
#   theme(
#     text = element_text(size = 30),
#     axis.text.x = element_text(size = 16, hjust = 1),
#     axis.text.y = element_text(size = 16, hjust = 1),
#     strip.text.y = element_blank(),  # Remove facet labels
#     panel.grid.major = element_blank(),  # Remove major grid lines
#     panel.grid.minor = element_blank(),  # Remove minor grid lines
#     plot.caption = element_text(size = 16, hjust = 0, vjust = -1),
#     plot.margin = margin(10, 10, 20, 10)
#   ) +
#   labs(
#     title = "Book Ban Instances Surge over the past Three Years",
#     subtitle = "Instances of Book Ban and Number of Book Titles Banned",
#     x = NULL,
#     y = NULL,
#     caption = "Data source: PEN America"
#   ) +
#   theme(legend.position = "none") +
#   scale_x_continuous(breaks = seq(0, 12000, by = 2000))  # Set breaks every 2000 units
